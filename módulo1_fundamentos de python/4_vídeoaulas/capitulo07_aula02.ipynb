# %% [markdown]
# # Capítulo 07 - Módulos

# %% [markdown]
# ## Aula 02 - Módulos Embutidos do Python

# %% [markdown]
# Módulo **`math`**: *modulo com funções matemáticas para cálculos mais complexos*

# %%
import math
print('Função cosseno:', math.cos(100))
# Out:
# Função cosseno: 0.8623188722876839

# %%
print('Função log:', math.log(10))
# Out:
# Função log: 2.302585092994046

# %% [markdown]
# Módulo **`itertools`**: *modulo para construção de sequências elaboradas*

# %%
import itertools

# combinação de 3 em 3
print(list(itertools.combinations([0, 1, 2, 3, 4], 2)))
# Out:
# [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]

# %%
 # permutação de 2 em 2
print(list(itertools.permutations(['a', 'b', 'c'], 2)))
# Out:
# [('a', 'b'), ('a', 'c'), ('b', 'a'), ('b', 'c'), ('c', 'a'), ('c', 'b')]

# %% [markdown]
# Módulo **`datetime`**: *modulo para manipulação de timestamps (datas, horários, deltas etc.)*

# %%
from datetime import datetime, timedelta
print('Datetime atual:', datetime.now())
# Out:
# Datetime atual: 2024-03-16 15:12:40.927082

# %%
print('Datetime após 7 dias:',  datetime.now() + timedelta(days=7))
# Out:
# Datetime após 7 dias: 2024-03-23 15:12:52.696701

# %% [markdown]
# Módulo **`random`**: *modulo para criação de números e sequências randômicas*

# %%
import random
print('Numero aleatório entre 0 e 1:', random.random())
# Out:
# Numero aleatório entre 0 e 1: 0.29271669417083157

# %%
print('Inteiro aleatório entre 50 e 100:', random.randint(50, 100))
# Out:
# Inteiro aleatório entre 50 e 100: 77

# %% [markdown]
# Módulo **`os`**: *modulo para funcionalidades que dependem do sistema operacional*

# %%
import os
os.mkdir('abacaxi') # cria um diretório chamado pasta

# %%
nome_pasta = 'abacaxi'
print('Caminho completo:', os.path.join('/home/antonio', nome_pasta, 'arquivo.txt'))
# Out:
# Caminho completo: /home/antonio/abacaxi/arquivo.txt

# %%
f'/home/antonio/{nome_pasta}/arquivo.txt'
# Out:
# '/home/antonio/abacaxi/arquivo.txt'

# %%
\home\antonio\abacaxi\arquivo.txt
